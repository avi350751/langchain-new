# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o")

# %%
llm.invoke("In which year America bombed Nagasaki?").content
# Out:
# 'America bombed Nagasaki on August 9, 1945.'
